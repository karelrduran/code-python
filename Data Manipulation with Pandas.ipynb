# %% [markdown]
# ### Data Manipulation with Pandas

# %%
# imports
import pandas as pd
import numpy as np

# %%
# Read a CSV file
df = pd.read_csv('data/taxis.csv')
df
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
# Display dataframe's columns
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
# Filter where clause
cash_payments = df[df['payment'] == 'cash']
cash_payments
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 10    2019-03-16 10:02:25  2019-03-16 10:22:29           1      3.90  17.0
# 13    2019-03-19 07:55:25  2019-03-19 08:09:17           1      1.75  10.5
# 14    2019-03-27 12:13:34  2019-03-27 12:25:48           0      2.90  11.5
# 15    2019-03-16 17:53:34  2019-03-16 18:13:57           3      2.09  13.5
# ...                   ...                  ...         ...       ...   ...
# 6420  2019-03-16 15:39:23  2019-03-16 15:46:18           2      1.20   7.0
# 6422  2019-03-22 20:17:35  2019-03-22 20:36:07           1      4.02  16.0
# 6424  2019-03-30 20:52:15  2019-03-30 20:59:55           1      1.70   8.0
# 6427  2019-03-23 18:26:09  2019-03-23 18:49:12           1      7.07  20.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
#
#       tip  tolls  total   color payment               pickup_zone  \
# ...

# %%
# Just select the columns: pickup_zone, dropoff_zone
cash_payments = cash_payments[['pickup_zone', 'dropoff_zone']]
cash_payments
# Out:
#                    pickup_zone                dropoff_zone
# 1        Upper West Side South       Upper West Side South
# 10           LaGuardia Airport                     Astoria
# 13         Lincoln Square West   Times Sq/Theatre District
# 14    Financial District North     Two Bridges/Seward Park
# 15       Upper West Side North                Clinton East
# ...                        ...                         ...
# 6420            Central Harlem       Upper West Side North
# 6422  Washington Heights South  Spuyten Duyvil/Kingsbridge
# 6424            Central Harlem        Central Harlem North
# 6427               Parkchester           East Harlem South
# 6430       Crown Heights North              Bushwick North
#
# [1812 rows x 2 columns]

# %%
# Put the filtered data into a new csv file
cash_payments.to_csv('data/filtered_cash_payments_with_pickup_dropoff.csv', index=False)
